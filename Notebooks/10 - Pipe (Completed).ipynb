# %% [markdown]
# #### PIPE - 10:
# This pipe covers the following :
# 1. All features of pipe 9
# 2. Create a main function by integrating all the subfunctions - C
# 3. Integrate custom area selection for tracking - C

# %%
from utils.runner_utils import run_detection

# %%
video_path='/media/hlink/hd/test_videos/testx_vid_1.mp4'
ssd=[
     {'id': 3, 'name': 'car', 'vehicle_class': 'lmv'},
     {'id': 4, 'name': 'motorcycle', 'vehicle_class': 'mcwg/mcg'},
     {'id': 5, 'name': 'truck', 'vehicle_class': 'hgmv'},
     {'id': 6, 'name': 'bus', 'vehicle_class': 'hpmv'},
     {'id': 7, 'name': 'rikshaw', 'vehicle_class': 'l5m'}
    ]
voi=[
   {'id': 2, 'name': 'over_speed'}, 
   {'id': 3, 'name': 'no_helmet'}
]

# %%
run_detection(video_file_path=video_path,camera_id="4",area_id="56",vehicle_json_arr=ssd,violation_json_arr=voi,area_selection=True,debug=True)
# Out:
# 2024-05-28 18:23:40.966 | SUCCESS  | boxmot.appearance.reid_model_factory:load_pretrained_weights:207 - Successfully loaded pretrained weights from "models/osnet_x0_25_msmt17.pt"
# tracking_area_coordinates--[{'x_start': 306, 'y_start': 135, 'x_end': 724, 'y_end': 376}, {'x_start': 306, 'y_start': 214, 'x_end': 724, 'y_end': 296}]
# entered if-
# Starting video inference
# ending video inference
# Json format is maintained True
# Debug Process 1 Completed
# Debug Process 2 Completed
# Debug Process 3 Completed
# Debug Process 4 Completed
# Debug Process 6 Completed

# %%
import torch
import gc

from ultralytics import YOLO
from transformers import TrOCRProcessor, VisionEncoderDecoderModel

def tr_ocr_model_loader(numthreads=3,cuda_on=True,model_name='microsoft/trocr-small-printed',device_number=0):
    """
    Model utils
    """
    if cuda_on:
        device = f'cuda:{device_number}' if torch.cuda.is_available() else 'cpu'
    else:
        device='cpu'
    model_json_list=[]
    for _ in range(numthreads):
        model_dict={}
        model = VisionEncoderDecoderModel.from_pretrained(model_name).to(device)
        processor = TrOCRProcessor.from_pretrained(model_name)
        # Loading params into temp json
        model_dict['device']=device
        model_dict['model_name']=model_name
        model_dict['model']=model
        model_dict['processor']=processor
        model_json_list.append(model_dict)
        print(f"Done_loading {_}")
    return model_json_list

# %%
tr_ocr_model_loader(numthreads=3,cuda_on=True,model_name='microsoft/trocr-small-printed',device_number=1)
# Out:
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-small-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# preprocessor_config.json:   0%|          | 0.00/272 [00:00<?, ?B/s]
# Done_loading 0
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-small-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Done_loading 1
# Some weights of VisionEncoderDecoderModel were not initialized from the model checkpoint at microsoft/trocr-small-printed and are newly initialized: ['encoder.pooler.dense.bias', 'encoder.pooler.dense.weight']
# ...

# %%
from utils.rectangle_utils import *
# Usage
video_path='/media/hlink/hd/test_videos/testx_vid_1.mp4'
# x,y = draw_rectangle_on_first_frame(video_path)
outer_rectangle_coords = draw_rectangle_on_first_frame(video_path)

# %%
outer_rectangle_coords
# Out:
# [{'x_start': 581, 'y_start': 746, 'x_end': 1042, 'y_end': 828},
#  {'x_start': 581, 'y_start': 721, 'x_end': 1042, 'y_end': 853}]
